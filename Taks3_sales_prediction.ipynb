# %% [raw]
# Project Name:Sales Prediction using Python
#
#
# Problem Statement:
#
#
#  Sales prediction means predicting how much of a product people will buy based on
#  factors
#  such as the amount you spend to advertise your product, the segment of people you
#  advertise for, or the platform you are advertising on about your product.
#  Typically, a product and service-based business always need their Data Scientist to
#  predict
#  their future sales with every step they take to manipulate the cost of advertising their
#  product. So let’s start the task of sales prediction with machine learning using Python

# %%
#importing liabraries
import pandas as pd
import numpy as np
import seaborn as sns
import os
import matplotlib.pyplot as plt

# %%
#reading files from the folder
os.chdir(r"C:\Users\maren\OneDrive\Desktop\CodeAlpha\project3")
os.listdir()
# Out:
# ['Advertising.csv']

# %%
#reading the data from Advertising.csv
sales_data=pd.read_csv('Advertising.csv',index_col=0)
sales_data.head(10)
# Out:
#        TV  Radio  Newspaper  Sales
# 1   230.1   37.8       69.2   22.1
# 2    44.5   39.3       45.1   10.4
# 3    17.2   45.9       69.3    9.3
# 4   151.5   41.3       58.5   18.5
# 5   180.8   10.8       58.4   12.9
# 6     8.7   48.9       75.0    7.2
# 7    57.5   32.8       23.5   11.8
# 8   120.2   19.6       11.6   13.2
# 9     8.6    2.1        1.0    4.8
# 10  199.8    2.6       21.2   10.6

# %%
#printing the shape of the dataset
sales_data.shape
# Out:
# (200, 4)

# %%
#checking if the data set has any null values 
sales_data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 7.8 KB

# %%
#statistical analysis of the dataset provided

sales_data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   14.022500
# std     85.854236   14.846809   21.778621    5.217457
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   10.375000
# 50%    149.750000   22.900000   25.750000   12.900000
# 75%    218.825000   36.525000   45.100000   17.400000
# max    296.400000   49.600000  114.000000   27.000000

# %% [raw]
# Visualization and Analysis

# %%
plt.scatter(sales_data['Sales'],sales_data['TV'],c='blue')
plt.title('Sales throungh TV ads')
plt.xlabel('TV')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.scatter(sales_data['Sales'],sales_data['Newspaper'],c='red')
plt.title('Sales throungh Newspaper ads')
plt.xlabel('Newspaper')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.scatter(sales_data['Sales'],sales_data['Radio'],c='green')
plt.title('Sales throungh Radio ads')
plt.xlabel('Radio')
plt.ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
plt.hist(sales_data['TV'],color='blue',edgecolor='black')

plt.xlabel('TV')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(sales_data['Newspaper'],color='red',edgecolor='blue')

plt.xlabel('Newspaper')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
plt.hist(sales_data['Radio'],color='green',edgecolor='red')

plt.xlabel('Radio')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#Checking Co-relation and plotting heatmap


sns.heatmap(sales_data.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(sales_data, hue="Sales", diag_kind="hist")

# %%
sns.pairplot(sales_data,hue='Sales')

# %%
#Seperating the data for Train and Test


from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(sales_data[['TV']],sales_data[['Sales']],test_size=0.2,random_state=0)

# %%
print(x_train)
# Out:
#         TV
# 135   36.9
# 67    31.5
# 27   142.9
# 114  209.6
# 169  215.4
# ..     ...
# 68   139.3
# 193   17.2
# 118   76.4
# 48   239.9
# 173   19.6
#
# [160 rows x 1 columns]

# %%
print(y_train)
# Out:
#      Sales
# 135   10.8
# 67     9.5
# 27    15.0
# 114   15.9
# 169   17.1
# ..     ...
# 68    13.4
# 193    5.9
# 118    9.4
# 48    23.2
# 173    7.6
#
# [160 rows x 1 columns]

# %%
print(x_test)
# Out:
#         TV
# 19    69.2
# 171   50.0
# 108   90.4
# 99   289.7
# 178  170.2
# 183   56.2
# 6      8.7
# 147  240.1
# 13    23.8
# 153  197.6
# 62   261.3
# 126   87.2
# 181  156.6
# 155  187.8
# 81    76.4
# 8    120.2
# 34   265.6
# 131    0.7
# 38    74.7
# 75   213.4
# 184  287.6
# 146  140.3
# 46   175.1
# 160  131.7
# 61    53.5
# 124  123.1
# 180  165.6
# 186  205.0
# 123  224.0
# 45    25.1
# 17    67.8
# 56   198.9
# 151  280.7
# 112  241.7
# 23    13.2
# 190   18.7
# 130   59.6
# 5    180.8
# 84    68.4
# 107   25.0

# %%
print(y_test)
# Out:
#      Sales
# 19    11.3
# 171    8.4
# 108    8.7
# 99    25.4
# 178   11.7
# 183    8.7
# 6      7.2
# 147   13.2
# 13     9.2
# 153   16.6
# 62    24.2
# 126   10.6
# 181   10.5
# 155   15.6
# 81    11.8
# 8     13.2
# 34    17.4
# 131    1.6
# 38    14.7
# 75    17.0
# 184   26.2
# 146   10.3
# 46    14.9
# 160   12.9
# 61     8.1
# 124   15.2
# 180   12.6
# 186   22.6
# 123   11.6
# 45     8.5
# 17    12.5
# 56    23.7
# 151   16.1
# 112   21.8
# 23     5.6
# 190    6.7
# 130    9.7
# 5     12.9
# 84    13.6
# 107    7.2

# %%
#Linear Regression for training the mmodel


from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
#prediction of TV ADS


repos=model.predict(x_test)
print(repos)
# Out:
# [[10.47623281]
#  [ 9.59288325]
#  [11.45159795]
#  [20.62095042]
#  [15.12301956]
#  [ 9.87813155]
#  [ 7.69276154]
#  [18.33896406]
#  [ 8.38747917]
#  [16.383633  ]
#  [19.3143292 ]
#  [11.30437303]
#  [14.49731363]
#  [15.93275666]
#  [10.8074889 ]
#  [12.82263008]
#  [19.51216269]
#  [ 7.32469923]
#  [10.72927566]
#  [17.11055607]
#  [20.52433406]
#  [13.74738665]
#  [15.34845773]
#  [13.35171966]
#  [ 9.75391052]
#  [12.95605267]
#  [14.91138373]
#  [16.72409064]
#  [17.59823864]
#  [ 8.44728929]
#  [10.41182191]
#  [16.44344313]
#  [20.20688032]
#  [18.41257652]
#  [ 7.8997966 ]
#  [ 8.15283944]
#  [10.03455803]
#  [15.61070213]
#  [10.43942658]
#  [ 8.44268851]]

# %%
#Coeficient

model.coef_
# Out:
# array([[0.04600779]])

# %%
#Intercept

model.intercept_
# Out:
# array([7.29249377])

# %%
0.04600779*69.2+7.29249377
# Out:
# 10.476232838

# %%
plt.plot(repos)

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test, 7.29249377 + 0.04600779*x_test,'r')
plt.show()

# %% [raw]
# Conclusion:
#
#
# Sales prediction is a crucial aspect for businesses to optimize their advertising strategies and forecast future revenue. By analyzing various factors such as advertising expenditure, target demographics, and advertising platforms, we can accurately predict product sales. This project demonstrated how machine learning techniques in Python can be leveraged to build predictive models that provide valuable insights into future sales trends. These predictions enable businesses to make informed decisions, enhance their marketing strategies, and better manage their resources. Leveraging data-driven insights through machine learning can significantly improve the efficiency and effectiveness of sales strategies.
